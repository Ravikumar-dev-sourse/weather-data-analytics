# %%
import pandas as pd

df = pd.read_csv("C:/Users/ELCOT/Documents/excel for data analytics/weather_data_project/dataset/weather_data.csv")

df
# Out:
#         city                 date  temperature  feels_like  humidity  \
# 0    Chennai  2026-08-24 18:59:55        30.43       37.43        79
# 1  Bengaluru  2026-08-24 18:59:56        22.72       23.32        87
# 2     Mumbai  2026-08-24 18:59:57        28.99       34.50        79
# 3      Delhi  2026-08-24 18:59:57        27.96       34.96       100
# 4  Hyderabad  2026-08-24 18:59:58        25.23       26.11        88
# 5    Kolkata  2026-08-24 18:59:58        28.97       35.97        89
#
#    pressure  wind_speed          weather  latitude  longitude
# 0      1006        3.09  overcast clouds   13.0878    80.2785
# 1      1012        4.63       light rain   12.9762    77.6033
# 2      1008        6.17       light rain   19.0144    72.8479
# 3      1002        2.06  overcast clouds   28.6667    77.2167
# 4      1009        4.12    moderate rain   17.3753    78.4744
# 5      1001        3.09    broken clouds   22.5697    88.3697

# %%
df.head()
# Out:
#         city                 date  temperature  feels_like  humidity  \
# 0    Chennai  2026-08-24 18:59:55        30.43       37.43        79
# 1  Bengaluru  2026-08-24 18:59:56        22.72       23.32        87
# 2     Mumbai  2026-08-24 18:59:57        28.99       34.50        79
# 3      Delhi  2026-08-24 18:59:57        27.96       34.96       100
# 4  Hyderabad  2026-08-24 18:59:58        25.23       26.11        88
#
#    pressure  wind_speed          weather  latitude  longitude
# 0      1006        3.09  overcast clouds   13.0878    80.2785
# 1      1012        4.63       light rain   12.9762    77.6033
# 2      1008        6.17       light rain   19.0144    72.8479
# 3      1002        2.06  overcast clouds   28.6667    77.2167
# 4      1009        4.12    moderate rain   17.3753    78.4744

# %%
df.shape
# Out:
# (6, 10)
